# %%
import sys
import re, numpy as np, pandas as pd

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# NLTK Stop words
from nltk.corpus import stopwords
import string

# %matplotlib inline
warnings.filterwarnings("ignore",category=DeprecationWarning)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %%
#Define stopwords
punctuation = "".join([symbol for symbol in string.punctuation if symbol not in ["'", '"']])
punctuation += '–'
punctuation += '...'

stopwords_list = stopwords.words('english')
stopwords_list += list(punctuation)

# %%
#Checking my list of stopwords
stopwords_list
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '!',
#  '#',
#  '$',
#  '%',
#  '&',
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  '–',
#  '.',
#  '.',
#  '.']

# %% [markdown]
# # Getting DF

# %%
#Importing dataframes
df = pd.read_pickle('script_TM')

# %%
df.shape
# Out:
# (1086, 2)

# %%
df.head(25)
# Out:
#                 Speaker                                               Text
# 0       COMPUTER SCREEN   So close it has no boundaries. A blinking cur...
# 1            MAN (V.O.)     Hello? Data now slashes across the screen, ...
# 2                SCREEN     Call trans opt:  received.   2-19-96  13:24...
# 3          WOMAN (V.O.)     I'm inside.  Anything to report? We listen ...
# 4              TRINITY.
# 5         CYPHER (V.O.)                    Let's see.  Target left work at
# 6              5:01 PM.
# 7                SCREEN     Trace program:  running. The entire screen ...
# 8         CYPHER (V.O.)     He caught the northbound Howard    line. Go...
# 9        TRINITY (V.O.)     All right, you're relieved.  Use   the usua...
# 10        CYPHER (V.O.)     Do you know when we're going to   make cont...
# 11              TRINITY                   Soon. Only two thin digits left.
# 12        CYPHER (V.O.)     Just between you and me, you don't    belie...
# 13       TRINITY (V.O.)                   I think Morpheus believes he is.
# 14        CYPHER (V.O.)                       I know.  But what about you?
# 15       TRINITY (V.O.)      I think Morpheus knows things that   I don't.
# 16        CYPHER (V.O.)     Yeah, but if he's wrong -- The final number...
# 17       TRINITY (V.O.)                                 Did you hear that?
# 18        CYPHER (V.O.)                                         Hear what?
# 19               SCREEN                      Trace complete.  Call origin:
# 20        #312-555-0690
# 21       TRINITY (V.O.)                   Are you sure this line is clean?
# 22        CYPHER (V.O.)     Yeah, course I'm sure. We MOVE STILL CLOSER...
# 23       TRINITY (V.O.)                                       I better go.
# 24       CYPHER (V.O.)      Yeah.  Right.  See you on the other side. S...

# %% [markdown]
# # Cleaning DF

# %%
df.Speaker.value_counts()
# Out:
#      NEO                     175
#      MORPHEUS                134
#      TRINITY                 120
#      AGENT SMITH              73
#      TANK                     60
#                             ...
#  BA-BOOM!                      1
#  INT.  TRAIN                   1
#  INT.  BAR (MATRIX) - DAY      1
#  EXT.  EL TRAIN                1
#  INT.  OVERFLOW PIT            1
# Name: Speaker, Length: 156, dtype: int64

# %%
df.Speaker.nunique()
# Out:
# 156

# %%
df.Speaker.unique()
# Out:
# array([' COMPUTER SCREEN', '     MAN (V.O.)', '     SCREEN',
#        '     WOMAN (V.O.)', ' TRINITY.', '     CYPHER (V.O.)',
#        '   5:01 PM.', '     TRINITY (V.O.)', '     TRINITY',
#        '   #312-555-0690', '     CYPHER (V.O.) ', '     RADIO (V.O.)',
#        ' INT.  CHASE HOTEL - NIGHT', '     BIG COP',
#        ' EXT.  CHASE HOTEL - NIGHT', '     AGENT SMITH',
#        '     LIEUTENANT', '     AGENT SMITH ', ' INT.  CHASE HOTEL',
#        ' FIRES --', ' EXT.  CHASE HOTEL', '     MORPHEUS (V.O.)',
#        ' INT.  HALL', ' EXT.  FIRE E5CAPE', ' EXT.  ROOF', '     COP',
#        ' EXT.  STREET', '     AGENT JONES', '   FOS4:  ALL HAIL SEGA!!!',
#        " INT.  NEO'S APARTMENT", '     NEO', '     VOICE (O.S.)',
#        '     ANTHONY', '     DUJOUR', ' INT.  APARTMENT',
#        '       CUT TO:', ' 9:15 A.M.', ' EXT.  SKYSCRAPER',
#        ' INT.  CORTECHS OFFICE', '     RHINEHEART',
#        " INT.  NEO'S CUBICLE", '     TALL EMPLOYEE', '     FEDEX',
#        ' INT.  INTERROGATION ROOM - CLOSE ON CAMERA MONITOR', ' A."',
#        " INT.  NEO'S APARTMENT - NIGHT", '     MORPHEUS (V.O.).',
#        ' EXT.  EL TRAIN', ' INT.  TRAIN', '     APOC', ' INT.  TRUCK BED',
#        ' EXT.  LOWER WACKER', '     GIZMO', ' INT.  VAN',
#        ' INT.  HOTEL LAFAYETTE', ' INT.  ROOM 1313', '     MORPHEUS',
#        '     CYPHER', " INT.  POWER PLANT - CLOSE ON MAN'S BODY",
#        ' INT.  WASTE LINE', ' INT.  HOVERCRAFT',
#        '         FADE TO BLACK.', '     MAN (O.S.)', '     WOMAN (O.S.)',
#        ' FADE IN:', " NEO'S POV", ' ANGLE ON NEO', '     DOZER',
#        " INT.  NEO'S ROOM", ' INT.  MAIN DECK', ' INT.  CONSTRUCT',
#        '     TANK',
#        ' INT.  MAIN DECK - CLOSE ON COMPUTER MONITOR - LATER',
#        ' INT.  DOJO', ' --', ' INT.  MESS HALL', '     MOUSE',
#        '     CABLE', '     SWITCH', ' EXT.  ROOFTOP', '     CYPHER,',
#        ' INT.  RESTAURANT (MATRIX) - NIGHT', '   R.S.I.', '   E.M.P?',
#        ' EXT.  CHICAGO (MATRIX) - DAY',
#        ' INT.  HOTEL LAFAYETTE (MATRIX) - DAY',
#        ' INT.  STAIRWELL (MATRIX) - DAY',
#        ' EXT.  HOTEL LAFAYETTE (MATRIX) - DAY',
#        ' INT.  LINCOLN CONTINENTAL (MATRIX) - DAY', '     MOJO',
#        ' EXT.  BAR (MATRIX) - DAY', ' INT.  BAR (MATRIX) - DAY',
#        '     REX', ' INT.  BASEMENT (MATRIX) - DAY',
#        ' INT.  TEMPLE OF ZION (MATRIX) - DAY', '     PRIESTESS',
#        ' INT.  ROOM OF POTENTIALS (MATRIX) - DAY', '     SPOON BOY',
#        ' INT.  SHRINE (MATRIX) - DAY',
#        " INT.  ORACLE'S CHAMBERS (MATRIX) - DAY", '     ORACLE (WOMAN)',
#        '     ORACLE', ' INT.  ANTECHAMBER (MATRIX) - DAY',
#        ' EXT.  CITY STREET (MATRIX) - DAY',
#        ' INT.  ROOM 1313 (MATRIX) - DAY', '     TANK (V.O.)',
#        ' INT.  STAIRCASE (MATRIX) - DAY', ' INT.  HALL (MATRIX) - DAY',
#        ' INT.  STAIRS (MATRIX) - DAY', ' INT.  LAFAYETTE (MATRIX) - DAY',
#        ' INT.  ROOM 808 (MATRIX) - DAY', '     AGENT BROWTJ',
#        ' INT.  WALL (MATRIX) - DAY', '     AGENT BROWN',
#        ' INT.  ROOM 608 (MATRIX) - DAY',
#        ' INT.  CATCH BASIN (MATRIX) - DAY',
#        ' INT.  SEWER MAIN (MATRIX) - DAY', '     COPS',
#        ' EXT.  STREET (MATRIX) - DAY', '    MORPHEUS',
#        ' INT.  APPLIANCE STORE (MATRIX) - DAY', ' INT. MAIN DECK',
#        ' EXT.  NIKO HOTEL (MATRIX) - DAY',
#        ' INT.  TOP FLOOR (MATRIX) - DAY',
#        ' INT.  PRESIDENTIAL SUITE (MATRIX) - DAY',
#        ' INT.  NIKO HOTEL (MATRIX) - DAY',
#        ' INT.  ELEVATORS (MATRIX) - DAY',
#        ' INT.  ELEVATOR SHAFT (MATRIX) - DAY',
#        ' INT.  LOBBY (MATRIX) - DAY', ' BA-BOOM!',
#        ' EXT.  ROOF (MATRIX) - DAY', '     PILOT', '     SERGEANT',
#        ' INTO VIEW --', ' FIRE.', ' HELICOPTER BEGIN TO DIE.',
#        ' EXT.  ROOFTOP (MATRIX) - DAY',
#        ' INT.  "EL" STATION (MATRIX) - DAY', '     OLD MAN', ' CLICK.',
#        ' INT.  SEWER MAIN', ' INT.  CAR (MATRIX) - DAY',
#        '     NEO (V.O.)', ' INT.  CAR',
#        ' INT.  "HEART OF CHICAGO" HOTEL (MATRIX) - DAY',
#        ' EXT.  ALLEY (MATRIX) - DAY', ' 305...  304...', ' BOOM.',
#        ' INT.  HOTEL HALL (MATRIX) - DAY',
#        ' INT.  ROOM 303 (MATRIX) - DAY', ' INT.  OVERFLOW PIT',
#        ' ON COMPUTER SCREEN', '     BOY', '     MOMMY',
#        '          FADE OUT.', '     THE END'], dtype=object)

# %% [markdown]
# * I need to remove all the V.O to keep only the names

# %%
#create a function that take a text and remove the "V.O" at the end

def remove_vo(text):
    
    #check the length of the split and evaluate the second part to VO
    if len(text.split()) == 2:
        if text.split()[1] in ['(V.O.)','(V.O.).']:
            return text.split()[0]
        else: 
            return text
    else:
        return text

# %%
#Use split to take the V.O at the end of the in the Speaker name
df.Speaker = df.Speaker.apply(lambda x: remove_vo(x))

# %%
print(df.shape)
df.tail(25)
# Out:
# (1086, 2)
#                                Speaker  \
# 1061   INT.  HOTEL HALL (MATRIX) - DAY
# 1062                  INT.  HOVERCRAFT
# 1063                           TRINITY
# 1064         INT.  HALL (MATRIX) - DAY
# 1065                       AGENT SMITH
# 1066                  INT.  HOVERCRAFT
# 1067     INT.  ROOM 303 (MATRIX) - DAY
# 1068                  INT.  HOVERCRAFT
# 1069                           TRINITY
# 1070                INT.  OVERFLOW PIT
# 1071                  INT.  HOVERCRAFT
# 1072                           TRINITY
# 1073                    FADE TO BLACK.
# 1074                          FADE IN:
# 1075                ON COMPUTER SCREEN
# 1076                               NEO
# 1077                               NEO
# 1078                               NEO
# 1079                               NEO
# 1080                               BOY
# 1081                             MOMMY
# 1082                               BOY
# 1083                             MOMMY
# 1084                         FADE OUT.
# 1085                           THE END
#
#                                                    Text
# 1061   The BLOW ECHOES deep in his mind. His eyes sn...
# 1062   Trinity screams as the monitors jump back to ...
# 1063                                        Now get up!
# 1064   Neo struggles, holding his chest, sitting up....
# 1065     Nooooo! Agent Smith pounds on the elevator ...
# 1066   A sentinel BLOWS a hole in Morpheus' right ar...
# 1067                   Neo dives for the RINGING PHONE.
# 1068   Machines split open the craft, pouring in, la...
# 1069                             Now! He turns the key.
# 1070   A blinding shock of white lights flood the ch...
# 1071   In the still darkness, only the humans are al...
# 1072     Neo? His eyes open.  Tears pour from her sm...
# 1073
# 1074
# 1075   as in the opening.  The cursor beating steadi...
# 1076     Hi.  It's me.  I know you're out   there.  ...
# 1077     I thought I should call and let   you know ...
# 1078     I know you're real proud of this   world yo...
# 1079     I've decided to make a few   changes. We SH...
# 1080                                     Mommy!  Mommy!
# 1081                                              What?
# 1082                         That man!  That man flies!
# 1083     Don't be silly, honey.  Men don't   fly. Th...
# 1084
# 1085

# %%
df.head(25)
# Out:
#              Speaker                                               Text
# 0    COMPUTER SCREEN   So close it has no boundaries. A blinking cur...
# 1                MAN     Hello? Data now slashes across the screen, ...
# 2             SCREEN     Call trans opt:  received.   2-19-96  13:24...
# 3              WOMAN     I'm inside.  Anything to report? We listen ...
# 4           TRINITY.
# 5             CYPHER                    Let's see.  Target left work at
# 6           5:01 PM.
# 7             SCREEN     Trace program:  running. The entire screen ...
# 8             CYPHER     He caught the northbound Howard    line. Go...
# 9            TRINITY     All right, you're relieved.  Use   the usua...
# 10            CYPHER     Do you know when we're going to   make cont...
# 11           TRINITY                   Soon. Only two thin digits left.
# 12            CYPHER     Just between you and me, you don't    belie...
# 13           TRINITY                   I think Morpheus believes he is.
# 14            CYPHER                       I know.  But what about you?
# 15           TRINITY      I think Morpheus knows things that   I don't.
# 16            CYPHER     Yeah, but if he's wrong -- The final number...
# 17           TRINITY                                 Did you hear that?
# 18            CYPHER                                         Hear what?
# 19            SCREEN                      Trace complete.  Call origin:
# 20     #312-555-0690
# 21           TRINITY                   Are you sure this line is clean?
# 22            CYPHER     Yeah, course I'm sure. We MOVE STILL CLOSER...
# 23           TRINITY                                       I better go.
# 24            CYPHER     Yeah.  Right.  See you on the other side. S...

# %%
sorted(list(df.Speaker.unique()))
# Out:
# ['          FADE OUT.',
#  '         FADE TO BLACK.',
#  '       CUT TO:',
#  '     AGENT BROWN',
#  '     AGENT BROWTJ',
#  '     AGENT JONES',
#  '     AGENT SMITH',
#  '     AGENT SMITH ',
#  '     ANTHONY',
#  '     APOC',
#  '     BIG COP',
#  '     BOY',
#  '     CABLE',
#  '     COP',
#  '     COPS',
#  '     CYPHER',
#  '     CYPHER,',
#  '     DOZER',
#  '     DUJOUR',
#  '     FEDEX',
#  '     GIZMO',
#  '     LIEUTENANT',
#  '     MAN (O.S.)',
#  '     MOJO',
#  '     MOMMY',
#  '     MORPHEUS',
#  '     MOUSE',
#  '     NEO',
#  '     OLD MAN',
#  '     ORACLE',
#  '     ORACLE (WOMAN)',
#  '     PILOT',
#  '     PRIESTESS',
#  '     REX',
#  '     RHINEHEART',
#  '     SCREEN',
#  '     SERGEANT',
#  '     SPOON BOY',
#  '     SWITCH',
#  '     TALL EMPLOYEE',
#  '     TANK',
#  '     THE END',
#  '     TRINITY',
#  '     VOICE (O.S.)',
#  '     WOMAN (O.S.)',
#  '    MORPHEUS',
#  '   #312-555-0690',
#  '   5:01 PM.',
#  '   E.M.P?',
#  '   FOS4:  ALL HAIL SEGA!!!',
#  '   R.S.I.',
#  ' --',
#  ' 305...  304...',
#  ' 9:15 A.M.',
#  ' A."',
#  ' ANGLE ON NEO',
#  ' BA-BOOM!',
#  ' BOOM.',
#  ' CLICK.',
#  ' COMPUTER SCREEN',
#  ' EXT.  ALLEY (MATRIX) - DAY',
#  ' EXT.  BAR (MATRIX) - DAY',
#  ' EXT.  CHASE HOTEL',
#  ' EXT.  CHASE HOTEL - NIGHT',
#  ' EXT.  CHICAGO (MATRIX) - DAY',
#  ' EXT.  CITY STREET (MATRIX) - DAY',
#  ' EXT.  EL TRAIN',
#  ' EXT.  FIRE E5CAPE',
#  ' EXT.  HOTEL LAFAYETTE (MATRIX) - DAY',
#  ' EXT.  LOWER WACKER',
#  ' EXT.  NIKO HOTEL (MATRIX) - DAY',
#  ' EXT.  ROOF',
#  ' EXT.  ROOF (MATRIX) - DAY',
#  ' EXT.  ROOFTOP',
#  ' EXT.  ROOFTOP (MATRIX) - DAY',
#  ' EXT.  SKYSCRAPER',
#  ' EXT.  STREET',
#  ' EXT.  STREET (MATRIX) - DAY',
#  ' FADE IN:',
#  ' FIRE.',
#  ' FIRES --',
#  ' HELICOPTER BEGIN TO DIE.',
#  ' INT.  "EL" STATION (MATRIX) - DAY',
#  ' INT.  "HEART OF CHICAGO" HOTEL (MATRIX) - DAY',
#  ' INT.  ANTECHAMBER (MATRIX) - DAY',
#  ' INT.  APARTMENT',
#  ' INT.  APPLIANCE STORE (MATRIX) - DAY',
#  ' INT.  BAR (MATRIX) - DAY',
#  ' INT.  BASEMENT (MATRIX) - DAY',
#  ' INT.  CAR',
#  ' INT.  CAR (MATRIX) - DAY',
#  ' INT.  CATCH BASIN (MATRIX) - DAY',
#  ' INT.  CHASE HOTEL',
#  ' INT.  CHASE HOTEL - NIGHT',
#  ' INT.  CONSTRUCT',
#  ' INT.  CORTECHS OFFICE',
#  ' INT.  DOJO',
#  ' INT.  ELEVATOR SHAFT (MATRIX) - DAY',
#  ' INT.  ELEVATORS (MATRIX) - DAY',
#  ' INT.  HALL',
#  ' INT.  HALL (MATRIX) - DAY',
#  ' INT.  HOTEL HALL (MATRIX) - DAY',
#  ' INT.  HOTEL LAFAYETTE',
#  ' INT.  HOTEL LAFAYETTE (MATRIX) - DAY',
#  ' INT.  HOVERCRAFT',
#  ' INT.  INTERROGATION ROOM - CLOSE ON CAMERA MONITOR',
#  ' INT.  LAFAYETTE (MATRIX) - DAY',
#  ' INT.  LINCOLN CONTINENTAL (MATRIX) - DAY',
#  ' INT.  LOBBY (MATRIX) - DAY',
#  ' INT.  MAIN DECK',
#  ' INT.  MAIN DECK - CLOSE ON COMPUTER MONITOR - LATER',
#  ' INT.  MESS HALL',
#  " INT.  NEO'S APARTMENT",
#  " INT.  NEO'S APARTMENT - NIGHT",
#  " INT.  NEO'S CUBICLE",
#  " INT.  NEO'S ROOM",
#  ' INT.  NIKO HOTEL (MATRIX) - DAY',
#  " INT.  ORACLE'S CHAMBERS (MATRIX) - DAY",
#  ' INT.  OVERFLOW PIT',
#  " INT.  POWER PLANT - CLOSE ON MAN'S BODY",
#  ' INT.  PRESIDENTIAL SUITE (MATRIX) - DAY',
#  ' INT.  RESTAURANT (MATRIX) - NIGHT',
#  ' INT.  ROOM 1313',
#  ' INT.  ROOM 1313 (MATRIX) - DAY',
#  ' INT.  ROOM 303 (MATRIX) - DAY',
#  ' INT.  ROOM 608 (MATRIX) - DAY',
#  ' INT.  ROOM 808 (MATRIX) - DAY',
#  ' INT.  ROOM OF POTENTIALS (MATRIX) - DAY',
#  ' INT.  SEWER MAIN',
#  ' INT.  SEWER MAIN (MATRIX) - DAY',
#  ' INT.  SHRINE (MATRIX) - DAY',
#  ' INT.  STAIRCASE (MATRIX) - DAY',
#  ' INT.  STAIRS (MATRIX) - DAY',
#  ' INT.  STAIRWELL (MATRIX) - DAY',
#  ' INT.  TEMPLE OF ZION (MATRIX) - DAY',
#  ' INT.  TOP FLOOR (MATRIX) - DAY',
#  ' INT.  TRAIN',
#  ' INT.  TRUCK BED',
#  ' INT.  VAN',
#  ' INT.  WALL (MATRIX) - DAY',
#  ' INT.  WASTE LINE',
#  ' INT. MAIN DECK',
#  ' INTO VIEW --',
#  " NEO'S POV",
#  ' ON COMPUTER SCREEN',
#  ' TRINITY.',
#  'CYPHER',
#  'MAN',
#  'MORPHEUS',
#  'NEO',
#  'RADIO',
#  'TANK',
#  'TRINITY',
#  'WOMAN']

# %%
len(df.Speaker.unique())
# Out:
# 154

# %%
len(df.loc[df['Speaker'] == '     NEO'])
# Out:
# 175

# %% [markdown]
# I need to delete extra space in speaker name

# %%
#create a function to remove space before the name
def remove_space(text):
    return " ".join(text.split())

# %%
#Use the function to remove extra space
df.Speaker = df.Speaker.apply(lambda x: remove_space(x))

# %%
len(df.Speaker.unique())
# Out:
# 146

# %%
df.Speaker.value_counts()
# Out:
# NEO                                       180
# MORPHEUS                                  166
# TRINITY                                   132
# AGENT SMITH                                74
# TANK                                       69
#                                          ...
# INT. WASTE LINE                             1
# ORACLE (WOMAN)                              1
# INT. POWER PLANT - CLOSE ON MAN'S BODY      1
# HELICOPTER BEGIN TO DIE.                    1
# EXT. LOWER WACKER                           1
# Name: Speaker, Length: 146, dtype: int64

# %%
df.loc[df['Speaker'] == 'NEO'].head()
# Out:
#    Speaker                                               Text
# 66     NEO     Fuckin' idiots don't know shit. He finishes...
# 69     NEO                                   What the hell...
# 72     NEO                         What do you want, Anthony?
# 74     NEO     You got the money this time? He holds up tw...
# 82     NEO          I don't know.  I have to work   tomorrow.

# %% [markdown]
# I need to delete all the cells without text --> len(text) == 0

# %%
#work with the cells without text

# %%
#Check if it is None or blank
# df.Text.iloc[4] == None #False
df.Text.iloc[4] == '' #True
# Out:
# True

# %%
#How many of these empty cells do I have?
len(df[df.Text == ''])
# Out:
# 20

# %%
df.head()
# Out:
#            Speaker                                               Text
# 0  COMPUTER SCREEN   So close it has no boundaries. A blinking cur...
# 1              MAN     Hello? Data now slashes across the screen, ...
# 2           SCREEN     Call trans opt:  received.   2-19-96  13:24...
# 3            WOMAN     I'm inside.  Anything to report? We listen ...
# 4         TRINITY.

# %%
df_cleaned = df[df.Text != ''].reset_index(drop=True)

# %%
df_cleaned.head()
# Out:
#            Speaker                                               Text
# 0  COMPUTER SCREEN   So close it has no boundaries. A blinking cur...
# 1              MAN     Hello? Data now slashes across the screen, ...
# 2           SCREEN     Call trans opt:  received.   2-19-96  13:24...
# 3            WOMAN     I'm inside.  Anything to report? We listen ...
# 4           CYPHER                    Let's see.  Target left work at

# %%
df_cleaned.shape
# Out:
# (1066, 2)

# %%
df_cleaned.Speaker.value_counts()
# Out:
# NEO                                                  180
# MORPHEUS                                             166
# TRINITY                                              132
# AGENT SMITH                                           74
# TANK                                                  69
#                                                     ...
# EXT. ROOF                                              1
# INT. CHASE HOTEL - NIGHT                               1
# INT. INTERROGATION ROOM - CLOSE ON CAMERA MONITOR      1
# INT. ROOM 303 (MATRIX) - DAY                           1
# EXT. LOWER WACKER                                      1
# Name: Speaker, Length: 132, dtype: int64

# %%
df_cleaned.head()
# Out:
#            Speaker                                               Text
# 0  COMPUTER SCREEN   So close it has no boundaries. A blinking cur...
# 1              MAN     Hello? Data now slashes across the screen, ...
# 2           SCREEN     Call trans opt:  received.   2-19-96  13:24...
# 3            WOMAN     I'm inside.  Anything to report? We listen ...
# 4           CYPHER                    Let's see.  Target left work at

# %%
df_cleaned['Movie'] = 'The Matrix'

# %%
df_cleaned.head()
# Out:
#            Speaker                                               Text  \
# 0  COMPUTER SCREEN   So close it has no boundaries. A blinking cur...
# 1              MAN     Hello? Data now slashes across the screen, ...
# 2           SCREEN     Call trans opt:  received.   2-19-96  13:24...
# 3            WOMAN     I'm inside.  Anything to report? We listen ...
# 4           CYPHER                    Let's see.  Target left work at
#
#         Movie
# 0  The Matrix
# 1  The Matrix
# 2  The Matrix
# 3  The Matrix
# 4  The Matrix

# %%
#Saving as pickle
import pickle 
with open('script_cleaned_TM.pkl', 'wb') as f:
            pickle.dump(df_cleaned, f)
