# %%
import sys
import re, numpy as np, pandas as pd

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# NLTK Stop words
from nltk.corpus import stopwords
import string

# %matplotlib inline
warnings.filterwarnings("ignore",category=DeprecationWarning)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %%
#Define stopwords
punctuation = "".join([symbol for symbol in string.punctuation if symbol not in ["'", '"']])
punctuation += '–'
punctuation += '...'

stopwords_list = stopwords.words('english')
stopwords_list += list(punctuation)

# %%
#Checking my list of stopwords
stopwords_list
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '!',
#  '#',
#  '$',
#  '%',
#  '&',
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  '–',
#  '.',
#  '.',
#  '.']

# %% [markdown]
# # Getting DF

# %%
#Importing dataframes
df = pd.read_pickle('script_TMReloaded.pkl')

# %%
df.shape
# Out:
# (778, 2)

# %%
df.head(25)
# Out:
#                        Speaker  \
# 0                        WOMAN
# 1                          MAN
# 2                        NIOBE
# 3                          MAN
# 4                        NIOBE
# 5                        NIOBE
# 6                          MAN
# 7   INT. NEBACHANEZZER COCKPIT
# 8                     MORPHEUS
# 9                        NIOBE
# 10                    MORPHEUS
# 11        INT. SEPHORA COCKPIT
# 12                       NIOBE
# 13        INT. FREEDOM COCKPIT
# 14                         MAN
# 15                       NIOBE
# 16           EXT. FREEDOM HULL
# 17        INT. SEPHORA COCKPIT
# 18                         MAN
# 19                       CIRCA
# 20                       NIOBE
# 21                       CIRCA
# 22                       CIRCA
# 23            INT. NEB COCKPIT
# 24        INT. SEPHORA COCKPIT
#
#                                                  Text
# 0              "Six o'clock, 300 meters. We can't ...
# 1       "I know. Can't tow this crate fast enough!...
# 2        "Can't, the core is still good. And they'...
# 3                "Oooh, our savior. Hed better be...
# 4                   "Shut up and make the exit. Ho...
# 5                                "Woo-hoooh!"The r...
# 6                           "They're still on us!"...
# 7   The NEB is slung between the two HOVERCRAFT, w...
# 8                           "Niobe, theyre closing."
# 9                                         "How many?"
# 10                "Just a few. Maybe two or three....
# 11  NIOBE, as regal as she is beautiful, sits at t...
# 12                 "Youve got a gift for understa...
# 13  THE  FREEDOMS CAPTAIN,  a silhouette  in a  d...
# 14         "Oh shit, were screwed. We gotta set d...
# 15                                        "Too many!"
# 16  A racing SQUIDDIES  reaches the hull  and latc...
# 17
# 18                   "Theyre on me! Shit! Losing ...
# 19                         "Multiple bogies closing!"
# 20                                         "No shit."
# 21                            "From the front!"Nio...
# 22                              "Are they - "She d...
# 23  A massive  swarm off  missiles blasts  by the ...
# 24  Niobe breathes a sigh of relief. Her lieutenan...

# %% [markdown]
# # Cleaning DF

# %%
df.Speaker.value_counts()
# Out:
#                                MORPHEUS      93
#                                  NEO         92
#                                 RAZOR        51
#                                TRINITY       49
#                                GREGORY       46
#                                              ..
# INT. BATHROOM HOUSE (MATRIX) - SUNSET         1
# CU: TANKS                                     1
#                              PILOT (V.O.)     1
# EXT. DESERT HIGHWAY (NIGHT)                   1
#                                SERGEANT       1
# Name: Speaker, Length: 171, dtype: int64

# %%
df.Speaker.nunique()
# Out:
# 171

# %%
df.Speaker.unique()
# Out:
# array(['                             WOMAN (V.O.)',
#        '                              MAN (V.O.)',
#        '                             NIOBE (V.O.)',
#        'INT. NEBACHANEZZER COCKPIT',
#        '                               MORPHEUS',
#        '                                NIOBE', 'INT. SEPHORA COCKPIT',
#        'INT. FREEDOM COCKPIT', '                                 MAN',
#        'EXT. FREEDOM HULL', '                                CIRCA',
#        'INT. NEB COCKPIT', '                         DEFENDER ONE (V.O.)',
#        'EXT. THE SURFACE', '                                 TANK',
#        '                               TRINITY',
#        '                                 NEO',
#        '                                                              FADE OUT',
#        'FADE INTO:',
#        '                                                               CUT TO:',
#        'INT. MAIN DECK, NEB', 'EXT. ZION TARMAC',
#        '                                 "M."',
#        '                                 CHOI',
#        '                                DUJOUR', 'EXT. ZION STREET',
#        '                               WAITRESS',
#        'EXT. MAIN STREET, ZION', 'INT. DEAD DUCK', 'EXT. TUNNEL',
#        'INT. MAIN DECK', '                                RAZOR',
#        'EXT. MOUNTAIN TOP, LATE DAY (CONSTRUCT)', 'INT. MAIN BRIDGE',
#        'EXT. GLADE (CONSTRUCT)', 'INT. OFFICE (MATRIX)',
#        '                             AGENT JONES',
#        '                             AGENT BROWN',
#        '                                JONES',
#        '                                BROWN',
#        '                          MAN\x92S VOICE (O.S.)',
#        '                               NEO."',
#        '                          ANGLE ON: THE DOOR',
#        '                                SMITH',
#        'EXT. DESERT HIGHWAY (NIGHT)',
#        '                               CHANDRA',
#        '                                 GREG', 'INT. CRUISER',
#        '                                 COP', 'EXT. HIGHWAY',
#        '                               GREGORY', 'INT. COP CAR',
#        'EXT. ROAD', 'EXT. CRUISER', 'EXT. BEACH', 'EXT. DUNES',
#        'EXT. CAMPFIRE', '                         CHOPPER LOUDSPEAKER',
#        '       "THIS IS THE POLICE, STOP YOUR VEHICLES AND SURRENDER!"',
#        'INT. HELICOPTER COCKPIT',
#        '                             PILOT (V.O.)', 'CHANDRA.',
#        'CU: GREGORY AND CHANDRA', 'CU: GUTTED CRUISER',
#        'EXT. GUTTED CRUISER', '                              LIEUTENANT',
#        'INT. MAIN BRIDGE (NIGHT)', 'INT. COCKPIT',
#        '                             RAZOR (V.O.)', 'INT. MORPHEUS CABIN',
#        '              SCREEN: LOGON ACCEPTED. WELCOME, MORPHEUS.',
#        '                     MISSION SPECS DOWNLOADING...',
#        '                              DOWNLOADED',
#        '                           LOGOUT COMPLETE',
#        '               MISSION TYPE: INFILTRATION / DESTRUCTION',
#        '                       TARGET: MATRIX MAINFRAME',
#        '                                  ?"', 'CUT TO: NEO',
#        'EXT. DESERT (DAY)', '                             GREGORY POV',
#        'EXT. DESERT ROCK', 'EXT. DESERT',
#        '                             MAN IN BLACK', 'AGENT SMITH.',
#        '                             AGENT SMITH', 'EXT. LAKE SHORE',
#        'CU: GREGORY', 'SMITH.', 'INT. COCKPIT (NIGHT)',
#        '                               MORPHUES',
#        '                           MORPHEUS (O.S.)',
#        'INT. ABANDONED WAREHOUSE',
#        '                             CIRCA (O.S.)',
#        'EXT. ABANDONED WAREHOUSE',
#        '                   POSTER: INTERNATIONAL TERRORISTS',
#        'EXT. DOWNTOWN STREET', '                               HOMELESS',
#        'EXT. FOREST GLADE', 'INT. OFFICE BUILDING', 'EXT. ROOFTOP',
#        'EXT. STREET', 'EXT. BUILDING ROOFTOP',
#        '                              REAL TIME',
#        'INT. METACORTEX OFFICE', 'EXT. METACORTEX PLAZA', 'CU: SOLDIERS',
#        '                               PRIVATE',
#        '                               SERGEANT', 'INT. TANK TURRET',
#        '                           CU: TANK GUNNER',
#        '                            POV: TANK SITE',
#        '                               CU: NEO',
#        '                           CU: AGENT SMITH',
#        '                                PILOT', 'EXT. HELICOPTER WING',
#        '              CU: AGM-65 HELLFIRE GROUND-TO-AIR-MISSILE',
#        '                        POV: HELLFIRE NOSE CAM', 'EXT. PLAZA',
#        'CU: PILOT', 'EXT. HELICOPTER',
#        '                            TANK COMMANDER', 'EXT. M1A2 ABRAMS',
#        'EXT. TANK', '                              CU: SMITH',
#        'EXT. ROOF', 'EXT. OFFICE', 'CU: SMITH',
#        '                                "HEY!"', 'EXT. CITY STREET',
#        'CU: NEO', 'INT. STAIRWAY', 'EXT. METACORTEX BUILDING',
#        'CU: AGENT BROWN', '                           MORPHEUS (V.O.)',
#        'INT. EMPTY BUILDING', 'INT. LOBBY', 'EXT. ALLEY (MATRIX) DAY',
#        'EXT. ALLEY - DAY', '                                WOMAN',
#        'EXT. ALLEY (MATRIX) - DAY', 'EXT. STREET (MATRIX) - DAY',
#        'CU: PHONE', 'CU: TANKS', 'CU: CHOI', 'EXT. STREET (MATRIX) DAY',
#        'CU: SOLDIER', 'CU: TRINITY', 'INT. COUNTACH (MATRIX) - DAY',
#        'EXT. HIGHWAY (MATRIX) - DAY',
#        'INT. APARTMENT BUILDING (MATRIX) - DAY', 'ORACLE.',
#        '                              PRIESTESS',
#        'EXT. ROOFTOP (MATRIX) - DAY', 'EXT. SKY (MATRIX) - DAY',
#        'CU: GREGOR', 'INT. SEWER (MATRIX) - DAY',
#        'EXT. DESERT HIGHWAY (MATRIX) - SUNSET',
#        'INT. COUNTACH (MATRIX) - SUNSET', 'INT. MAIN DECK - NIGHT',
#        'INT. MAIN DECK (NIGHT)', 'INT. COUNTACH (MATRIX) SUNSET',
#        '                             RAZOR (O.S.)',
#        'EXT. REST STOP (MATRIX) - SUNSET',
#        'INT. BATHROOM HOUSE (MATRIX) - SUNSET',
#        'EXT. REST STOP (MATRIX) - NIGHT', 'EXT. REST STOP',
#        'EXT. REST STOP (MATRIX)', 'EXT. BOOTH (MATRIX) - SUNSET',
#        'INT. PENTHOUSE APARTMENT (MATRIX) - NIGHT',
#        'INT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT',
#        'EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT'], dtype=object)

# %% [markdown]
# * I need to remove all the V.O to keep only the names

# %%
#create a function that take a text and remove the "V.O" at the end

def remove_vo(text):
    
    #check the length of the split and evaluate the second part to VO
    if len(text.split()) == 2:
        if text.split()[1] in ['(V.O.)','(V.O.).','(V.O. )']:
            return text.split()[0]
        else: 
            return text
    else:
        return text

# %%
#Use split to take the V.O at the end of the in the Speaker name
df.Speaker = df.Speaker.apply(lambda x: remove_vo(x))

# %%
print(df.shape)
df.tail(25)
# Out:
# (778, 2)
#                                         Speaker  \
# 753                                         NEO
# 754                                    MORPHEUS
# 755                                         NEO
# 756                      INT. MAIN DECK - NIGHT
# 757                                    MORPHEUS
# 758   EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
# 759                                         NEO
# 760                             MORPHEUS (O.S.)
# 761                                         NEO
# 762                                         NEO
# 763                             MORPHEUS (O.S.)
# 764                                         NEO
# 765                      INT. MAIN DECK - NIGHT
# 766                                    MORPHEUS
# 767   EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
# 768                                         NEO
# 769                             MORPHEUS (O.S.)
# 770                             MORPHEUS (O.S.)
# 771                                         NEO
# 772                      INT. MAIN DECK - NIGHT
# 773                                    MORPHEUS
# 774   EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
# 775                      INT. MAIN DECK - NIGHT
# 776                                    MORPHEUS
# 777   EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
#
#                                                   Text
# 753         "Morpheus! Holy shit! You wont believe...
# 754                                          "I know."
# 755             "I couldnt do it. Morpheus, there...
# 756         MORPHEUS has the headset on. He stands ...
# 757              "Yes, there is a problem. The Matr...
# 758                    NEOS relief fades into conf...
# 759                               "I know. Im sorry."
# 760                            "And the problem is..."
# 761   "Uh, its impossible. If the Matrix is destro...
# 762                      "Morpheus? Did you know th...
# 763                "I didnt say things would be ea...
# 764                                              "No."
# 765  MORPHEUS isnt happy about what he has to tell...
# 766     "Neo, the Matrix... its not real. And its...
# 767  NEO cant stand the reality of the situation. ...
# 768    "No, Morpheus, this cant be! We cant do th...
# 769   "Even if we could somehow get to them without...
# 770                    "You can do it. You can free...
# 771               "Why me? Why the fuck do I have t...
# 772  Everyone is watching  Morpheus, and no  one ca...
# 773  "You know what needs to be done. Time is short...
# 774  Neo hears the line click dead. He cant believ...
# 775  MORPHEUS drops the headset on  the operations ...
# 776                    "No one goes in. Hes on his...
# 777  Neo closes the cell  phone. He reaches to  tuc...

# %% [markdown]
# I need to remove (O.S) in the name of the speaker

# %%
#create a function that take a text and remove the "O.S" at the end

def remove_os(text):
    
    #check the length of the split and evaluate the second part to VO
    if len(text.split()) == 2:
        if text.split()[1] in ['(O.S.)','(O.S.).', ' (O.S.)']:
            return text.split()[0]
        else: 
            return text
    else:
        return text

# %%
#Use split to take the O.S at the end of the in the Speaker name
df.Speaker = df.Speaker.apply(lambda x: remove_os(x))

# %%
#Checking the result
print(df.shape)
df.tail(25)
# Out:
# (778, 2)
#                                        Speaker  \
# 753                                        NEO
# 754                                   MORPHEUS
# 755                                        NEO
# 756                     INT. MAIN DECK - NIGHT
# 757                                   MORPHEUS
# 758  EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
# 759                                        NEO
# 760                                   MORPHEUS
# 761                                        NEO
# 762                                        NEO
# 763                                   MORPHEUS
# 764                                        NEO
# 765                     INT. MAIN DECK - NIGHT
# 766                                   MORPHEUS
# 767  EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
# 768                                        NEO
# 769                                   MORPHEUS
# 770                                   MORPHEUS
# 771                                        NEO
# 772                     INT. MAIN DECK - NIGHT
# 773                                   MORPHEUS
# 774  EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
# 775                     INT. MAIN DECK - NIGHT
# 776                                   MORPHEUS
# 777  EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
#
#                                                   Text
# 753         "Morpheus! Holy shit! You wont believe...
# 754                                          "I know."
# 755             "I couldnt do it. Morpheus, there...
# 756         MORPHEUS has the headset on. He stands ...
# 757              "Yes, there is a problem. The Matr...
# 758                    NEOS relief fades into conf...
# 759                               "I know. Im sorry."
# 760                            "And the problem is..."
# 761   "Uh, its impossible. If the Matrix is destro...
# 762                      "Morpheus? Did you know th...
# 763                "I didnt say things would be ea...
# 764                                              "No."
# 765  MORPHEUS isnt happy about what he has to tell...
# 766     "Neo, the Matrix... its not real. And its...
# 767  NEO cant stand the reality of the situation. ...
# 768    "No, Morpheus, this cant be! We cant do th...
# 769   "Even if we could somehow get to them without...
# 770                    "You can do it. You can free...
# 771               "Why me? Why the fuck do I have t...
# 772  Everyone is watching  Morpheus, and no  one ca...
# 773  "You know what needs to be done. Time is short...
# 774  Neo hears the line click dead. He cant believ...
# 775  MORPHEUS drops the headset on  the operations ...
# 776                    "No one goes in. Hes on his...
# 777  Neo closes the cell  phone. He reaches to  tuc...

# %%
df.head(25)
# Out:
#                                     Speaker  \
# 0                                     WOMAN
# 1                                       MAN
# 2                                     NIOBE
# 3                                       MAN
# 4                                     NIOBE
# 5                                     NIOBE
# 6                                       MAN
# 7                INT. NEBACHANEZZER COCKPIT
# 8                                  MORPHEUS
# 9                                     NIOBE
# 10                                 MORPHEUS
# 11                     INT. SEPHORA COCKPIT
# 12                                    NIOBE
# 13                     INT. FREEDOM COCKPIT
# 14                                      MAN
# 15                                    NIOBE
# 16                        EXT. FREEDOM HULL
# 17                     INT. SEPHORA COCKPIT
# 18                                      MAN
# 19                                    CIRCA
# 20                                    NIOBE
# 21                                    CIRCA
# 22                                    CIRCA
# 23                         INT. NEB COCKPIT
# 24                     INT. SEPHORA COCKPIT
#
#                                                  Text
# 0              "Six o'clock, 300 meters. We can't ...
# 1       "I know. Can't tow this crate fast enough!...
# 2        "Can't, the core is still good. And they'...
# 3                "Oooh, our savior. Hed better be...
# 4                   "Shut up and make the exit. Ho...
# 5                                "Woo-hoooh!"The r...
# 6                           "They're still on us!"...
# 7   The NEB is slung between the two HOVERCRAFT, w...
# 8                           "Niobe, theyre closing."
# 9                                         "How many?"
# 10                "Just a few. Maybe two or three....
# 11  NIOBE, as regal as she is beautiful, sits at t...
# 12                 "Youve got a gift for understa...
# 13  THE  FREEDOMS CAPTAIN,  a silhouette  in a  d...
# 14         "Oh shit, were screwed. We gotta set d...
# 15                                        "Too many!"
# 16  A racing SQUIDDIES  reaches the hull  and latc...
# 17
# 18                   "Theyre on me! Shit! Losing ...
# 19                         "Multiple bogies closing!"
# 20                                         "No shit."
# 21                            "From the front!"Nio...
# 22                              "Are they - "She d...
# 23  A massive  swarm off  missiles blasts  by the ...
# 24  Niobe breathes a sigh of relief. Her lieutenan...

# %%
sorted(list(df.Speaker.unique()))
# Out:
# ['"HEY!"',
#  '"M."',
#  '"THIS IS THE POLICE, STOP YOUR VEHICLES AND SURRENDER!"',
#  '?"',
#  'AGENT BROWN',
#  'AGENT JONES',
#  'AGENT SMITH',
#  'AGENT SMITH.',
#  'ANGLE ON: THE DOOR',
#  'BROWN',
#  'CHANDRA',
#  'CHANDRA.',
#  'CHOI',
#  'CHOPPER LOUDSPEAKER',
#  'CIRCA',
#  'COP',
#  'CU: AGENT BROWN',
#  'CU: AGENT SMITH',
#  'CU: AGM-65 HELLFIRE GROUND-TO-AIR-MISSILE',
#  'CU: CHOI',
#  'CU: GREGOR',
#  'CU: GREGORY',
#  'CU: GREGORY AND CHANDRA',
#  'CU: GUTTED CRUISER',
#  'CU: NEO',
#  'CU: PHONE',
#  'CU: PILOT',
#  'CU: SMITH',
#  'CU: SOLDIER',
#  'CU: SOLDIERS',
#  'CU: TANK GUNNER',
#  'CU: TANKS',
#  'CU: TRINITY',
#  'CUT TO:',
#  'CUT TO: NEO',
#  'DEFENDER ONE (V.O.)',
#  'DOWNLOADED',
#  'DUJOUR',
#  'EXT. ABANDONED WAREHOUSE',
#  'EXT. ALLEY (MATRIX) - DAY',
#  'EXT. ALLEY (MATRIX) DAY',
#  'EXT. ALLEY - DAY',
#  'EXT. BEACH',
#  'EXT. BOOTH (MATRIX) - SUNSET',
#  'EXT. BUILDING ROOFTOP',
#  'EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT',
#  'EXT. CAMPFIRE',
#  'EXT. CITY STREET',
#  'EXT. CRUISER',
#  'EXT. DESERT',
#  'EXT. DESERT (DAY)',
#  'EXT. DESERT HIGHWAY (MATRIX) - SUNSET',
#  'EXT. DESERT HIGHWAY (NIGHT)',
#  'EXT. DESERT ROCK',
#  'EXT. DOWNTOWN STREET',
#  'EXT. DUNES',
#  'EXT. FOREST GLADE',
#  'EXT. FREEDOM HULL',
#  'EXT. GLADE (CONSTRUCT)',
#  'EXT. GUTTED CRUISER',
#  'EXT. HELICOPTER',
#  'EXT. HELICOPTER WING',
#  'EXT. HIGHWAY',
#  'EXT. HIGHWAY (MATRIX) - DAY',
#  'EXT. LAKE SHORE',
#  'EXT. M1A2 ABRAMS',
#  'EXT. MAIN STREET, ZION',
#  'EXT. METACORTEX BUILDING',
#  'EXT. METACORTEX PLAZA',
#  'EXT. MOUNTAIN TOP, LATE DAY (CONSTRUCT)',
#  'EXT. OFFICE',
#  'EXT. PLAZA',
#  'EXT. REST STOP',
#  'EXT. REST STOP (MATRIX)',
#  'EXT. REST STOP (MATRIX) - NIGHT',
#  'EXT. REST STOP (MATRIX) - SUNSET',
#  'EXT. ROAD',
#  'EXT. ROOF',
#  'EXT. ROOFTOP',
#  'EXT. ROOFTOP (MATRIX) - DAY',
#  'EXT. SKY (MATRIX) - DAY',
#  'EXT. STREET',
#  'EXT. STREET (MATRIX) - DAY',
#  'EXT. STREET (MATRIX) DAY',
#  'EXT. TANK',
#  'EXT. THE SURFACE',
#  'EXT. TUNNEL',
#  'EXT. ZION STREET',
#  'EXT. ZION TARMAC',
#  'FADE INTO:',
#  'FADE OUT',
#  'GREG',
#  'GREGORY',
#  'GREGORY POV',
#  'HOMELESS',
#  'INT. ABANDONED WAREHOUSE',
#  'INT. APARTMENT BUILDING (MATRIX) - DAY',
#  'INT. BATHROOM HOUSE (MATRIX) - SUNSET',
#  'INT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT',
#  'INT. COCKPIT',
#  'INT. COCKPIT (NIGHT)',
#  'INT. COP CAR',
#  'INT. COUNTACH (MATRIX) - DAY',
#  'INT. COUNTACH (MATRIX) - SUNSET',
#  'INT. COUNTACH (MATRIX) SUNSET',
#  'INT. CRUISER',
#  'INT. DEAD DUCK',
#  'INT. EMPTY BUILDING',
#  'INT. FREEDOM COCKPIT',
#  'INT. HELICOPTER COCKPIT',
#  'INT. LOBBY',
#  'INT. MAIN BRIDGE',
#  'INT. MAIN BRIDGE (NIGHT)',
#  'INT. MAIN DECK',
#  'INT. MAIN DECK (NIGHT)',
#  'INT. MAIN DECK - NIGHT',
#  'INT. MAIN DECK, NEB',
#  'INT. METACORTEX OFFICE',
#  'INT. MORPHEUS CABIN',
#  'INT. NEB COCKPIT',
#  'INT. NEBACHANEZZER COCKPIT',
#  'INT. OFFICE (MATRIX)',
#  'INT. OFFICE BUILDING',
#  'INT. PENTHOUSE APARTMENT (MATRIX) - NIGHT',
#  'INT. SEPHORA COCKPIT',
#  'INT. SEWER (MATRIX) - DAY',
#  'INT. STAIRWAY',
#  'INT. TANK TURRET',
#  'JONES',
#  'LIEUTENANT',
#  'LOGOUT COMPLETE',
#  'MAN',
#  'MAN IN BLACK',
#  'MAN\x92S VOICE (O.S.)',
#  'MISSION SPECS DOWNLOADING...',
#  'MISSION TYPE: INFILTRATION / DESTRUCTION',
#  'MORPHEUS',
#  'MORPHUES',
#  'NEO',
#  'NEO."',
#  'NIOBE',
#  'ORACLE.',
#  'PILOT',
#  'POSTER: INTERNATIONAL TERRORISTS',
#  'POV: HELLFIRE NOSE CAM',
#  'POV: TANK SITE',
#  'PRIESTESS',
#  'PRIVATE',
#  'RAZOR',
#  'REAL TIME',
#  'SCREEN: LOGON ACCEPTED. WELCOME, MORPHEUS.',
#  'SERGEANT',
#  'SMITH',
#  'SMITH.',
#  'TANK',
#  'TANK COMMANDER',
#  'TARGET: MATRIX MAINFRAME',
#  'TRINITY',
#  'WAITRESS',
#  'WOMAN']

# %%
len(df.Speaker.unique())
# Out:
# 169

# %%
len(df.loc[df['Speaker'] == '     NEO'])
# Out:
# 0

# %% [markdown]
# I need to delete extra space in speaker name

# %%
#create a function to remove space before the name
def remove_space(text):
    return " ".join(text.split())

# %%
#Use the function to remove extra space
df.Speaker = df.Speaker.apply(lambda x: remove_space(x))

# %%
len(df.Speaker.unique())
# Out:
# 160

# %%
df.Speaker.value_counts()
# Out:
# MORPHEUS                       104
# NEO                             92
# RAZOR                           53
# TRINITY                         49
# GREGORY                         46
#                               ...
# EXT. ROAD                        1
# EXT. ZION STREET                 1
# GREG                             1
# EXT. DESERT HIGHWAY (NIGHT)      1
# TARGET: MATRIX MAINFRAME         1
# Name: Speaker, Length: 160, dtype: int64

# %%
df.loc[df['Speaker'] == 'NEO'].head()
# Out:
#    Speaker                                               Text
# 31     NEO                                     "What's that?"
# 38     NEO                                 "Who is this guy?"
# 41     NEO                         "What happened to him?"...
# 42     NEO                            "Was he like me?"   ...
# 44     NEO                   "No. I've never been a big sl...

# %%
len(df.loc[df['Speaker'] == 'NEO'])
# Out:
# 92

# %% [markdown]
# I need to delete all the cells without text --> len(text) == 0

# %%
#work with the cells without text

# %%
#Check if it is None or blank
# df.Text.iloc[4] == None #False
df.Text.iloc[4] == '' #True
# Out:
# False

# %%
#How many of these empty cells do I have?
len(df[df.Text == ''])
# Out:
# 37

# %%
df.head()
# Out:
#   Speaker                                               Text
# 0   WOMAN             "Six o'clock, 300 meters. We can't ...
# 1     MAN      "I know. Can't tow this crate fast enough!...
# 2   NIOBE       "Can't, the core is still good. And they'...
# 3     MAN               "Oooh, our savior. Hed better be...
# 4   NIOBE                  "Shut up and make the exit. Ho...

# %%
df_cleaned = df[df.Text != ''].reset_index(drop=True)

# %%
df_cleaned.head()
# Out:
#   Speaker                                               Text
# 0   WOMAN             "Six o'clock, 300 meters. We can't ...
# 1     MAN      "I know. Can't tow this crate fast enough!...
# 2   NIOBE       "Can't, the core is still good. And they'...
# 3     MAN               "Oooh, our savior. Hed better be...
# 4   NIOBE                  "Shut up and make the exit. Ho...

# %%
df_cleaned.shape
# Out:
# (741, 2)

# %%
df_cleaned.Speaker.value_counts()
# Out:
# MORPHEUS                    104
# NEO                          92
# RAZOR                        53
# TRINITY                      49
# GREGORY                      46
#                            ...
# HOMELESS                      1
# INT. COP CAR                  1
# EXT. ROAD                     1
# EXT. ZION STREET              1
# TARGET: MATRIX MAINFRAME      1
# Name: Speaker, Length: 146, dtype: int64

# %%
df_cleaned.Speaker.unique()
# Out:
# array(['WOMAN', 'MAN', 'NIOBE', 'INT. NEBACHANEZZER COCKPIT', 'MORPHEUS',
#        'INT. SEPHORA COCKPIT', 'INT. FREEDOM COCKPIT',
#        'EXT. FREEDOM HULL', 'CIRCA', 'INT. NEB COCKPIT',
#        'DEFENDER ONE (V.O.)', 'EXT. THE SURFACE', 'TANK', 'TRINITY',
#        'NEO', 'FADE OUT', 'FADE INTO:', 'INT. MAIN DECK, NEB',
#        'EXT. ZION TARMAC', 'CHOI', 'DUJOUR', 'EXT. ZION STREET',
#        'WAITRESS', 'EXT. MAIN STREET, ZION', 'INT. DEAD DUCK',
#        'EXT. TUNNEL', 'INT. MAIN DECK', 'RAZOR',
#        'EXT. MOUNTAIN TOP, LATE DAY (CONSTRUCT)', 'INT. MAIN BRIDGE',
#        'EXT. GLADE (CONSTRUCT)', 'INT. OFFICE (MATRIX)', 'AGENT JONES',
#        'AGENT BROWN', 'JONES', 'BROWN', 'MAN\x92S VOICE (O.S.)',
#        'ANGLE ON: THE DOOR', 'SMITH', 'EXT. DESERT HIGHWAY (NIGHT)',
#        'CHANDRA', 'GREG', 'INT. CRUISER', 'COP', 'EXT. HIGHWAY',
#        'GREGORY', 'INT. COP CAR', 'EXT. ROAD', 'EXT. CRUISER',
#        'EXT. BEACH', 'EXT. DUNES', 'EXT. CAMPFIRE',
#        '"THIS IS THE POLICE, STOP YOUR VEHICLES AND SURRENDER!"',
#        'INT. HELICOPTER COCKPIT', 'PILOT', 'CU: GREGORY AND CHANDRA',
#        'CU: GUTTED CRUISER', 'EXT. GUTTED CRUISER', 'LIEUTENANT',
#        'INT. MAIN BRIDGE (NIGHT)', 'INT. COCKPIT', 'INT. MORPHEUS CABIN',
#        'TARGET: MATRIX MAINFRAME', '?"', 'CUT TO: NEO',
#        'EXT. DESERT (DAY)', 'GREGORY POV', 'EXT. DESERT ROCK',
#        'EXT. DESERT', 'MAN IN BLACK', 'AGENT SMITH.', 'AGENT SMITH',
#        'EXT. LAKE SHORE', 'CU: GREGORY', 'INT. COCKPIT (NIGHT)',
#        'MORPHUES', 'INT. ABANDONED WAREHOUSE', 'EXT. ABANDONED WAREHOUSE',
#        'POSTER: INTERNATIONAL TERRORISTS', 'EXT. DOWNTOWN STREET',
#        'HOMELESS', 'EXT. FOREST GLADE', 'INT. OFFICE BUILDING',
#        'EXT. ROOFTOP', 'EXT. STREET', 'EXT. BUILDING ROOFTOP',
#        'REAL TIME', 'INT. METACORTEX OFFICE', 'EXT. METACORTEX PLAZA',
#        'CU: SOLDIERS', 'PRIVATE', 'SERGEANT', 'CU: TANK GUNNER',
#        'POV: TANK SITE', 'CU: NEO',
#        'CU: AGM-65 HELLFIRE GROUND-TO-AIR-MISSILE',
#        'POV: HELLFIRE NOSE CAM', 'EXT. PLAZA', 'CU: PILOT',
#        'EXT. HELICOPTER', 'TANK COMMANDER', 'EXT. M1A2 ABRAMS',
#        'INT. TANK TURRET', 'EXT. TANK', 'CU: SMITH', 'EXT. ROOF',
#        'EXT. OFFICE', '"HEY!"', 'EXT. CITY STREET', 'INT. STAIRWAY',
#        'EXT. METACORTEX BUILDING', 'CU: AGENT BROWN',
#        'INT. EMPTY BUILDING', 'INT. LOBBY', 'EXT. ALLEY (MATRIX) DAY',
#        'EXT. ALLEY - DAY', 'EXT. ALLEY (MATRIX) - DAY', 'CU: PHONE',
#        'EXT. STREET (MATRIX) - DAY', 'CU: TANKS', 'CU: CHOI',
#        'EXT. STREET (MATRIX) DAY', 'CU: SOLDIER', 'CU: TRINITY',
#        'INT. COUNTACH (MATRIX) - DAY', 'EXT. HIGHWAY (MATRIX) - DAY',
#        'INT. APARTMENT BUILDING (MATRIX) - DAY', 'ORACLE.', 'PRIESTESS',
#        'EXT. ROOFTOP (MATRIX) - DAY', 'CU: GREGOR',
#        'INT. SEWER (MATRIX) - DAY',
#        'EXT. DESERT HIGHWAY (MATRIX) - SUNSET',
#        'INT. COUNTACH (MATRIX) - SUNSET', 'INT. MAIN DECK - NIGHT',
#        'INT. MAIN DECK (NIGHT)', 'INT. COUNTACH (MATRIX) SUNSET',
#        'EXT. REST STOP (MATRIX) - SUNSET',
#        'INT. BATHROOM HOUSE (MATRIX) - SUNSET',
#        'EXT. REST STOP (MATRIX) - NIGHT', 'EXT. REST STOP',
#        'EXT. REST STOP (MATRIX)', 'EXT. BOOTH (MATRIX) - SUNSET',
#        'INT. PENTHOUSE APARTMENT (MATRIX) - NIGHT',
#        'INT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT',
#        'EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT'], dtype=object)

# %%
# I need to remove the CU: at the beginning of some names

# %%
#create a function that take a text and remove the "C.U" at the beginning

def remove_cu(text):
    
    #check the length of the split and evaluate the second part to VO
    if len(text.split())>=2:
        if text.split()[0] in ['CU:']:
            return " ".join(text.split()[1:])
        else: 
            return text
    else:
        return text

# %%
#testing the function
remove_cu('CU: GREGORY AND CHANDRA')
# Out:
# 'GREGORY AND CHANDRA'

# %%
#Use the function to take the CU and other things in the Speaker name
df_cleaned.Speaker = df_cleaned.Speaker.apply(lambda x: remove_cu(x))

# %%
len(df_cleaned.Speaker.unique())
# Out:
# 139

# %%
df_cleaned.Speaker.unique()
# Out:
# array(['WOMAN', 'MAN', 'NIOBE', 'INT. NEBACHANEZZER COCKPIT', 'MORPHEUS',
#        'INT. SEPHORA COCKPIT', 'INT. FREEDOM COCKPIT',
#        'EXT. FREEDOM HULL', 'CIRCA', 'INT. NEB COCKPIT',
#        'DEFENDER ONE (V.O.)', 'EXT. THE SURFACE', 'TANK', 'TRINITY',
#        'NEO', 'FADE OUT', 'FADE INTO:', 'INT. MAIN DECK, NEB',
#        'EXT. ZION TARMAC', 'CHOI', 'DUJOUR', 'EXT. ZION STREET',
#        'WAITRESS', 'EXT. MAIN STREET, ZION', 'INT. DEAD DUCK',
#        'EXT. TUNNEL', 'INT. MAIN DECK', 'RAZOR',
#        'EXT. MOUNTAIN TOP, LATE DAY (CONSTRUCT)', 'INT. MAIN BRIDGE',
#        'EXT. GLADE (CONSTRUCT)', 'INT. OFFICE (MATRIX)', 'AGENT JONES',
#        'AGENT BROWN', 'JONES', 'BROWN', 'MAN\x92S VOICE (O.S.)',
#        'ANGLE ON: THE DOOR', 'SMITH', 'EXT. DESERT HIGHWAY (NIGHT)',
#        'CHANDRA', 'GREG', 'INT. CRUISER', 'COP', 'EXT. HIGHWAY',
#        'GREGORY', 'INT. COP CAR', 'EXT. ROAD', 'EXT. CRUISER',
#        'EXT. BEACH', 'EXT. DUNES', 'EXT. CAMPFIRE',
#        '"THIS IS THE POLICE, STOP YOUR VEHICLES AND SURRENDER!"',
#        'INT. HELICOPTER COCKPIT', 'PILOT', 'GREGORY AND CHANDRA',
#        'GUTTED CRUISER', 'EXT. GUTTED CRUISER', 'LIEUTENANT',
#        'INT. MAIN BRIDGE (NIGHT)', 'INT. COCKPIT', 'INT. MORPHEUS CABIN',
#        'TARGET: MATRIX MAINFRAME', '?"', 'CUT TO: NEO',
#        'EXT. DESERT (DAY)', 'GREGORY POV', 'EXT. DESERT ROCK',
#        'EXT. DESERT', 'MAN IN BLACK', 'AGENT SMITH.', 'AGENT SMITH',
#        'EXT. LAKE SHORE', 'INT. COCKPIT (NIGHT)', 'MORPHUES',
#        'INT. ABANDONED WAREHOUSE', 'EXT. ABANDONED WAREHOUSE',
#        'POSTER: INTERNATIONAL TERRORISTS', 'EXT. DOWNTOWN STREET',
#        'HOMELESS', 'EXT. FOREST GLADE', 'INT. OFFICE BUILDING',
#        'EXT. ROOFTOP', 'EXT. STREET', 'EXT. BUILDING ROOFTOP',
#        'REAL TIME', 'INT. METACORTEX OFFICE', 'EXT. METACORTEX PLAZA',
#        'SOLDIERS', 'PRIVATE', 'SERGEANT', 'TANK GUNNER', 'POV: TANK SITE',
#        'AGM-65 HELLFIRE GROUND-TO-AIR-MISSILE', 'POV: HELLFIRE NOSE CAM',
#        'EXT. PLAZA', 'EXT. HELICOPTER', 'TANK COMMANDER',
#        'EXT. M1A2 ABRAMS', 'INT. TANK TURRET', 'EXT. TANK', 'EXT. ROOF',
#        'EXT. OFFICE', '"HEY!"', 'EXT. CITY STREET', 'INT. STAIRWAY',
#        'EXT. METACORTEX BUILDING', 'INT. EMPTY BUILDING', 'INT. LOBBY',
#        'EXT. ALLEY (MATRIX) DAY', 'EXT. ALLEY - DAY',
#        'EXT. ALLEY (MATRIX) - DAY', 'PHONE', 'EXT. STREET (MATRIX) - DAY',
#        'TANKS', 'EXT. STREET (MATRIX) DAY', 'SOLDIER',
#        'INT. COUNTACH (MATRIX) - DAY', 'EXT. HIGHWAY (MATRIX) - DAY',
#        'INT. APARTMENT BUILDING (MATRIX) - DAY', 'ORACLE.', 'PRIESTESS',
#        'EXT. ROOFTOP (MATRIX) - DAY', 'GREGOR',
#        'INT. SEWER (MATRIX) - DAY',
#        'EXT. DESERT HIGHWAY (MATRIX) - SUNSET',
#        'INT. COUNTACH (MATRIX) - SUNSET', 'INT. MAIN DECK - NIGHT',
#        'INT. MAIN DECK (NIGHT)', 'INT. COUNTACH (MATRIX) SUNSET',
#        'EXT. REST STOP (MATRIX) - SUNSET',
#        'INT. BATHROOM HOUSE (MATRIX) - SUNSET',
#        'EXT. REST STOP (MATRIX) - NIGHT', 'EXT. REST STOP',
#        'EXT. REST STOP (MATRIX)', 'EXT. BOOTH (MATRIX) - SUNSET',
#        'INT. PENTHOUSE APARTMENT (MATRIX) - NIGHT',
#        'INT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT',
#        'EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT'], dtype=object)

# %%
df_cleaned.head(25)
# Out:
#                        Speaker  \
# 0                        WOMAN
# 1                          MAN
# 2                        NIOBE
# 3                          MAN
# 4                        NIOBE
# 5                        NIOBE
# 6                          MAN
# 7   INT. NEBACHANEZZER COCKPIT
# 8                     MORPHEUS
# 9                        NIOBE
# 10                    MORPHEUS
# 11        INT. SEPHORA COCKPIT
# 12                       NIOBE
# 13        INT. FREEDOM COCKPIT
# 14                         MAN
# 15                       NIOBE
# 16           EXT. FREEDOM HULL
# 17                         MAN
# 18                       CIRCA
# 19                       NIOBE
# 20                       CIRCA
# 21                       CIRCA
# 22            INT. NEB COCKPIT
# 23        INT. SEPHORA COCKPIT
# 24                       NIOBE
#
#                                                  Text
# 0              "Six o'clock, 300 meters. We can't ...
# 1       "I know. Can't tow this crate fast enough!...
# 2        "Can't, the core is still good. And they'...
# 3                "Oooh, our savior. Hed better be...
# 4                   "Shut up and make the exit. Ho...
# 5                                "Woo-hoooh!"The r...
# 6                           "They're still on us!"...
# 7   The NEB is slung between the two HOVERCRAFT, w...
# 8                           "Niobe, theyre closing."
# 9                                         "How many?"
# 10                "Just a few. Maybe two or three....
# 11  NIOBE, as regal as she is beautiful, sits at t...
# 12                 "Youve got a gift for understa...
# 13  THE  FREEDOMS CAPTAIN,  a silhouette  in a  d...
# 14         "Oh shit, were screwed. We gotta set d...
# 15                                        "Too many!"
# 16  A racing SQUIDDIES  reaches the hull  and latc...
# 17                   "Theyre on me! Shit! Losing ...
# 18                         "Multiple bogies closing!"
# 19                                         "No shit."
# 20                            "From the front!"Nio...
# 21                              "Are they - "She d...
# 22  A massive  swarm off  missiles blasts  by the ...
# 23  Niobe breathes a sigh of relief. Her lieutenan...
# 24                                    "They're ours."

# %%
df_cleaned.tail(25)
# Out:
#                                        Speaker  \
# 716                                        NEO
# 717                                   MORPHEUS
# 718                                        NEO
# 719                     INT. MAIN DECK - NIGHT
# 720                                   MORPHEUS
# 721  EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
# 722                                        NEO
# 723                                   MORPHEUS
# 724                                        NEO
# 725                                        NEO
# 726                                   MORPHEUS
# 727                                        NEO
# 728                     INT. MAIN DECK - NIGHT
# 729                                   MORPHEUS
# 730  EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
# 731                                        NEO
# 732                                   MORPHEUS
# 733                                   MORPHEUS
# 734                                        NEO
# 735                     INT. MAIN DECK - NIGHT
# 736                                   MORPHEUS
# 737  EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
# 738                     INT. MAIN DECK - NIGHT
# 739                                   MORPHEUS
# 740  EXT. BURNT-OUT CATHEDRAL (MATRIX) - NIGHT
#
#                                                   Text
# 716         "Morpheus! Holy shit! You wont believe...
# 717                                          "I know."
# 718             "I couldnt do it. Morpheus, there...
# 719         MORPHEUS has the headset on. He stands ...
# 720              "Yes, there is a problem. The Matr...
# 721                    NEOS relief fades into conf...
# 722                               "I know. Im sorry."
# 723                            "And the problem is..."
# 724   "Uh, its impossible. If the Matrix is destro...
# 725                      "Morpheus? Did you know th...
# 726                "I didnt say things would be ea...
# 727                                              "No."
# 728  MORPHEUS isnt happy about what he has to tell...
# 729     "Neo, the Matrix... its not real. And its...
# 730  NEO cant stand the reality of the situation. ...
# 731    "No, Morpheus, this cant be! We cant do th...
# 732   "Even if we could somehow get to them without...
# 733                    "You can do it. You can free...
# 734               "Why me? Why the fuck do I have t...
# 735  Everyone is watching  Morpheus, and no  one ca...
# 736  "You know what needs to be done. Time is short...
# 737  Neo hears the line click dead. He cant believ...
# 738  MORPHEUS drops the headset on  the operations ...
# 739                    "No one goes in. Hes on his...
# 740  Neo closes the cell  phone. He reaches to  tuc...

# %%
df_cleaned['Movie'] = 'The Matrix Reloaded'

# %%
df_cleaned  = df_cleaned.drop(columns = 'Movie#')

# %%
df_cleaned.head()
# Out:
#   Speaker                                               Text  \
# 0   WOMAN             "Six o'clock, 300 meters. We can't ...
# 1     MAN      "I know. Can't tow this crate fast enough!...
# 2   NIOBE       "Can't, the core is still good. And they'...
# 3     MAN               "Oooh, our savior. Hed better be...
# 4   NIOBE                  "Shut up and make the exit. Ho...
#
#                  Movie
# 0  The Matrix Reloaded
# 1  The Matrix Reloaded
# 2  The Matrix Reloaded
# 3  The Matrix Reloaded
# 4  The Matrix Reloaded

# %%
#Saving as pickle
import pickle 
with open('script_cleaned_TMR.pkl', 'wb') as f:
            pickle.dump(df_cleaned, f)
